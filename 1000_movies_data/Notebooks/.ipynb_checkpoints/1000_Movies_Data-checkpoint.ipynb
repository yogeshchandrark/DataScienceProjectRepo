# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../Data/External/1000_movies_data.csv')
df
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df['Rating'].unique()
# Out:
# array([8.1, 7. , 7.3, 7.2, 6.2, 6.1, 8.3, 6.4, 7.1, 7.5, 7.8, 7.9, 7.7,
#        6.6, 8.2, 6.7, 8. , 6.5, 5.3, 6.8, 4.7, 5.9, 6.3, 5.6, 8.6, 7.6,
#        6.9, 2.7, 3.7, 5.8, 9. , 7.4, 4.1, 8.5, 8.8, 5.4, 6. , 5.7, 8.4,
#        5.2, 5.5, 4.8, 3.9, 4.9, 5.1, 5. , 4.3, 4.6, 4.2, 4. , 3.2, 4.5,
#        1.9, 3.5, 4.4])

# %%
df['Rating'].max()
# Out:
# 9.0

# %%
df['Year'].unique().sort()

# %%
df['Year'].unique()
# Out:
# array([2014, 2012, 2016, 2015, 2007, 2011, 2008, 2006, 2009, 2010, 2013],
#       dtype=int64)

# %%
years = df['Year'].unique()

# %%
years
# Out:
# array([2014, 2012, 2016, 2015, 2007, 2011, 2008, 2006, 2009, 2010, 2013],
#       dtype=int64)

# %%
years.sort()

# %%
years
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#       dtype=int64)

# %%
 df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df['Director'].count()
# Out:
# 1000

# %%
directors = df['Director'].unique()

# %%
directors.sort()

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df[(df['Rank']<1001) & (df['Year'] < 2010)].count()[['Title', 'Year', 'Genre', 'Revenue (Millions)']]
# Out:
# Title                 200
# Year                  200
# Genre                 200
# Revenue (Millions)    189
# dtype: int64

# %%
imdb = pd.read_csv('../Data/External/IMDB-Movie-Data.csv')
imdb
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
df[(df['Rank']<101) & (df['Rating'] < 7)].count()[['Title', 'Year', 'Genre', 'Rating']]
# Out:
# Title     35
# Year      35
# Genre     35
# Rating    35
# dtype: int64
